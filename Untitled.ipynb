# %%
import pandas as pd

# %%
data = pd.read_csv('data/bitstampUSD_1-min_data_2012-01-01_to_2020-04-22.csv')
df = data.rename(columns={"Volume_(Currency)": "Currency", "Volume_(BTC)":"BTC"})
df.head()
# Out:
#     Timestamp  Open  High   Low  Close       BTC  Currency  Weighted_Price
# 0  1325317920  4.39  4.39  4.39   4.39  0.455581       2.0            4.39
# 1  1325317980   NaN   NaN   NaN    NaN       NaN       NaN             NaN
# 2  1325318040   NaN   NaN   NaN    NaN       NaN       NaN             NaN
# 3  1325318100   NaN   NaN   NaN    NaN       NaN       NaN             NaN
# 4  1325318160   NaN   NaN   NaN    NaN       NaN       NaN             NaN

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://omer:1234@localhost:5432/omerdb')

# %%
print(engine)
# Out:
# Engine(postgresql://omer:***@localhost:5432/omerdb)

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql://omer:1234@localhost:5432/omerdb')

chunksize=10000
i=0
j=0

for df in pd.read_csv('data/bitstampUSD_1-min_data_2012-01-01_to_2020-04-22.csv',delimiter=',',names=['Timestamp','Open','High','Low','Close','BTC','Currency','Weighted_Price'],chunksize=chunksize,iterator=True):
#     df = df.rename(columns={"Volume_(Currency)": "Currency", "Volume_(BTC)":"BTC"})
#     df = df.rename(columns = {c: c.replace(' ','') for c in df.columns})
    df.index += j
    print(df.head())
    df.to_sql('bitcoin_data101',engine,if_exists='append')
    j = df.index[-1]+1
    print('| index: {}'.format(j))
# Out:
#     Timestamp  Open  High   Low  Close           BTC           Currency  \
# 0   Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)
# 1  1325317920  4.39  4.39  4.39   4.39    0.45558087       2.0000000193
# 2  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0  Weighted_Price
# 1            4.39
# 2             NaN
# 3             NaN
# 4             NaN
# | index: 10000
#         Timestamp  Open  High  Low  Close  BTC  Currency  Weighted_Price
# 20000  1325917860   NaN   NaN  NaN    NaN  NaN       NaN             NaN
# 20001  1325917920   NaN   NaN  NaN    NaN  NaN       NaN             NaN
# 20002  1325917980   NaN   NaN  NaN    NaN  NaN       NaN             NaN
# 20003  1325918040   NaN   NaN  NaN    NaN  NaN       NaN             NaN
# ...
